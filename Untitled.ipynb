# %%
# %pip install pandas
import pandas as pd
df_solar = pd.read_csv('sgu-solar-installations-2011-to-present-and-totals.csv')
df_capacity = pd.read_csv('sgu-solar-capacity-2011-to-present-and-totals.csv')
# Out:
# Requirement already satisfied: pandas in c:\users\turkht\source\repos\jupyterlab\.venv\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\turkht\source\repos\jupyterlab\.venv\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\turkht\source\repos\jupyterlab\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\turkht\source\repos\jupyterlab\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\turkht\source\repos\jupyterlab\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\TurkhT\source\repos\JupyterLab\.venv\Scripts\python.exe -m pip install --upgrade pip
