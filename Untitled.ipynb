# %%
# %pip install pandas
import pandas as pd
df_solar = pd.read_csv('sgu-solar-installations-2011-to-present-and-totals.csv')
df_capacity = pd.read_csv('sgu-solar-capacity-2011-to-present-and-totals.csv')
df_population = pd.read_csv('Australian-Population-1981.csv')
df_state_pop = pd.read_csv('State-Population-1981.csv')
# Out:
# Requirement already satisfied: pandas in c:\users\tturb\appdata\local\programs\python\python313\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\tturb\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tturb\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\tturb\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\tturb\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: C:\Users\tturb\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
df_state = df_state_pop[df_state_pop["Year"].str.contains("Dec")].reset_index(drop=True)

df_state.columns = df_state.columns.str.strip()
df_state.columns = df_state.columns.str.replace("Estimated Resident Population ; ", "", regex=False)
df_state.columns = df_state.columns.str.replace(" ;", "", regex=False)

df_state = df_state[["Year"] + list(df_state.filter(like="Persons").columns)]
df_state.columns = df_state.columns.str.replace("Persons", "", regex=False)
df_state["Year"] = df_state["Year"].str.replace("Dec-", "", regex=False)
df_state = df_state.set_index("Year")
z
df_state.index = df_state.index.astype(int)
df_state.head(10)
# Out:
#       New South Wales  Victoria  Queensland  South Australia  \
# Year
# 1981          5266894   3968398     2387943          1325176
# 1982          5328221   4012687     2456475          1337783
# 1983          5374915   4054498     2503285          1353208
# 1984          5431752   4097640     2547078          1365333
# 1985          5496467   4140421     2597100          1376838
# 1986          5574251   4183842     2648778          1387499
# 1987          5666219   4234945     2703516          1398959
# 1988          5752254   4295300     2780869          1412323
# 1989          5803079   4348225     2864007          1425461
# 1990          5862497   4400707     2928713          1438882
#
#       Western Australia  Tasmania  Northern Territory  \
# Year
# 1981            1320221    428283              127718
# 1982            1354971    430974              132784
# 1983            1381011    435100              139519
# 1984            1403032    440070              145293
# 1985            1436900    444576              152356
# 1986            1477398    448235              156578
# 1987            1513355    449820              159040
# 1988            1558914    452781              160536
# 1989            1596225    458410              162097
# 1990            1624390    464520              165047
#
#       Australian Capital Territory  Australia
# Year
# 1981                        229484   15054117
# 1982                        234996   15288891
# 1983                        241960   15483496
# 1984                        247084   15677282
# 1985                        255908   15900566
# 1986                        262188   16138769
# 1987                        268787   16394641
# 1988                        274105   16687082
# 1989                        279219   16936723
# 1990                        285012   17169768
