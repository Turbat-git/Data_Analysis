# %% [markdown]
# # Portfolio 2 (POR2)
# ## Data Normalisation, KMeans Clustering, and Hypothesis Testing Portfolio Assessment Task
#
# **Objective:**
# Provides single-instance evidence for the performance of the following tasks related to ICTDAT502 and ICTDAT503:
# - Use unsupervised machine learning methodologies for clustering
# - Identify and conduct data normalising methodologies to develop a hypothesis used for significance testing
# - Plan and conduct a significance test on extracted and normalised data and conclude the finding
# - Understand (demonstrate knowledge) of data normalising methodologies used in data analysis and data reporting

# %% [markdown]
# ## **Assessment Tasks Overview**
#
# 1. **Data Preparation and Normalisation**
#    - Load the provided dataset.
#    - Evaluate and prepare the data.
#    - Apply data normalisation techniques.
#
# 2. **KMeans Clustering Analysis**
#    - Determine the optimal number of clusters using the Elbow Method and Silhouette Scores.
#    - Perform KMeans clustering using Sklearn.
#    - Evaluate clustering using Silhouette Score.
#    - Visualise and interpret the clusters.
#
# 3. **Cluster Evaluation and Interpretation**
#    - Generate a confusion matrix comparing true labels and cluster labels.
#    - Interpret the confusion matrix.
#
# 4. **Hypothesis Development and Significance Testing**
#    - Develop a simple hypothesis related to the clustering results.
#    - Conduct a significance test to validate the hypothesis.
#    - Conclude findings based on the test results.

# %% [markdown]
# ### Submission Requirements
#
# #### Artefacts
# - **Jupyter Notebook (.ipynb file):** Include all code cells, outputs, and markdown explanations.
# - **Code Quality:** Ensure your code is well-organised and commented where necessary.
# - **Execution:** All code cells should run without errors, and outputs should be displayed.
#
#
# #### Validity
# - Ensure that all tasks are completed as per instructions.
# - Provide clear and concise explanations in markdown cells.
# - You can use generative AI to **assist** you in completing your work.
# - **However:**
#   - You must be prepared and able to explain the purpose and function of all code you submit
#   - You should trim, edit, and validate all generated code
#   - **All** answers should be in your own words
#
#
# #### Resubmission
#
# - If you receive a **NYC** in any criterion, you can address the feedback and resubmit your work.
# - Typically, resubmissions must be uploaded within two weeks of receiving feedback
#
# ### Additional Support
# - If you require assistance understanding the tasks or criteria, please get in touch with your instructor.
# - Additional resources are available via Blackboard.

# %% [markdown]
# ## Instructions
#
# You will be working with the **Iris dataset**, a well-known dataset in machine learning and statistics. The dataset consists of 150 samples of iris flowers from three different species, with four features measured for each sample.
#
# Follow the steps outlined in this Jupyter Notebook to document your work. Use Python code cells for the code and markdown cells for explanations, when prompted.

# %% [markdown]
# ## Data Preparation and Normalisation

# %% [markdown]
# ### Load the Dataset

# %% [markdown]
# #### Import necessary libraries and load the Iris dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %% [markdown]
# #### Task: Identify the providence of the data and its original and target type
#
# 1. Find the GitHub URL from where the data is loaded
# > https://github.com/mwaskom/seaborn-data/blob/master/iris.csv
#
# 2. How is the original data stored?
# > The original data is stored in a CSV file format
#
#
# 4. What type is referenced by the `iris` variable (include code below that demonstrates how you figured it out)
# > pandas.DataFrame
#
# 6. Add code to show the first five rows of the data set

# %%
# Your code here
type(iris)
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #### Evaluate the Data
#
# ##### Task: Check for missing values and data types
# Fill in the code below to match the requirements in the comments

# %%
# Check for missing values
print(iris.isnull().sum())

# Check data types of each column
iris.dtypes
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species             str
# dtype: object

# %% [markdown]
# #### Task: reflect on data quality
#
# Given the information you gleaned from the code you wrote previously, write a brief paragraph about the quality of the data, whether additional preprocessing is required (or not), and why. Include in your answer:
# - Are there missing values?
# - Are all features numeric, and what are their types?

# %% [markdown]
# *Add Your Observations Here (1-2 paragraphs)*
#
# The Iris dataset is a clean and well-structured dataset. After checking for missing values using isnull().sum(), no missing values were found in any column. This means there is no need for data cleaning or imputation before analysis. All four feature columns (sepal_length, sepal_width, petal_length, and petal_width) are numeric and stored as float64 data types. The species column is stored as an object/string type because it contains categorical labels.

# %% [markdown]
# #### Data Normalisation
#
# We apply a StandardScaler to normalise the features of the data set. You do not need to change the code below, but you do need to be able to explain it.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()


df_scaled = iris.copy()
df_scaled.iloc[:,:-1] = scaler.fit_transform(df_scaled.iloc[:,:-1])


df_scaled.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0     -0.900681     1.019004     -1.340227    -1.315444  setosa
# 1     -1.143017    -0.131979     -1.340227    -1.315444  setosa
# 2     -1.385353     0.328414     -1.397064    -1.315444  setosa
# 3     -1.506521     0.098217     -1.283389    -1.315444  setosa
# 4     -1.021849     1.249201     -1.340227    -1.315444  setosa

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #### Task: Understand scaling and its importance
#
# 1. Identify in the scikit-learn documentation where the information on StandardScaler is, and explain in your own words (1-2 sentences) including the URL you used.
#
# > StandardScaler standardises features by removing the mean and scaling the data to unit variance. This means each feature will have an average value close to 0 and a standard deviation close to 1.
# > https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
#
# 2. Based on your reading, is StandardScalar sensitive to outliers? What page did the scikit-learn documentation propose to compare the effect of different scalars on outliers?
#
# > Yes, StandardScaler is sensitive to outliers because it uses the mean and standard deviation when scaling the data. Extreme values can heavily influence both calculations.
# >
#
#
# 3. Is data normalization relevant for KMeans clustering? Why/Why not? Consider the effect of the scale of a feature on its contribution to distance calculations.
#
# > Yes, normalization is very important for KMeans clustering because KMeans relies on Euclidean distance calculations. Features with larger numeric ranges contribute more heavily to distance measurements and may dominate the clustering process. Scaling ensures that all features contribute more equally.
#
# 4. What does this code snippet achieve `iloc[:,:-1]`, and what error would you get if you didn't use it?
#
# > iloc[:,:-1] selects all rows and all columns except the final column. I will get a value error because scaler only works on numeric values and the final column is a string.
#
# After you have evaluated the scaled model, you will be asked to try again with an unscaled model. Before you do, try and guess which model will perform better and why (your answer here will **not** be graded, so just give your best guess):
#
# > I expect the scaled model to perform better because all features will contribute equally during distance calculations.

# %% [markdown]
# ## KMeans Clustering Analysis
#
# ### Task Determine the Optimal Number of Clusters
#
# The code below calculates and plots inertia for various cluster sizes for KMeans. But there is a small bug in the code that you will need to fix before it will run successfully!

# %%
from sklearn.cluster import KMeans

k_values = range(1, 10)
inertia = []
# features = df_scaled.iloc[:, :-1]
iris.iloc[:, :-1].head()
features = iris.iloc[:, :-1]
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(features)
    inertia.append(kmeans.inertia_)

# Plot the Elbow Curve
plt.figure(figsize=(8, 4))
plt.plot(k_values, inertia, 'bo-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.xticks(k_values)
plt.show()

# %% [markdown]
# *Task (cont.) Reflect on your analysis here*
#
# 1. Given the diagram, what is the optimal number of clusters?
#
# > Three is the optimal number of clusters.
#
# 2. Provide your reasoning. Include in your answer what is inertia, and why the elbow method is called the elbow method
#
# > The elbow method is called the elbow method because the graph often forms an elbow-like bend. The optimal number of clusters is where adding more clusters no longer reduces as much.

# %% [markdown]
# ### Task: Examine cluster separation
#
# Another measure that is commonly used with K-Means clustering is the silhouette score. The silhouette score identifies how close points are to the peers in their respective clusters compared to points in other clusters. It provides a score between -1 and 1. A score of 1 suggests clearly defined boundaries between clusters (points within a cluster are grouped closer together, and each cluster is far from other clusters). Negative scores suggest misclassifying points to clusters (and may often indicate a process error rather than a data set feature).
# > **Note**: You have to fix the bug in the previous code for this to run!

# %%
from sklearn.metrics import silhouette_score

k_values = range(2, 7)
silhouette_scores = []

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    cluster_labels = kmeans.fit_predict(features)
    silhouette_avg = silhouette_score(features, cluster_labels)
    silhouette_scores.append(silhouette_avg)

# Plot the Silhouette Scores
plt.figure(figsize=(8, 4))
plt.plot(k_values, silhouette_scores, 'bo-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score For Different k')
plt.xticks(k_values)
plt.show()

# %% [markdown]
# *Task (cont.) Reflect on your analysis here*
#
# 1. Given the diagram, what number of clusters gives the best cluster separation?
#
# > Two is the best cluster separation.
#
# 2. Discuss how you would reason about the optimal number of clusters given the results of the two previous line charts. Include in your answer why you might be motivated to pick a larger number of clusters than the number offering the best sillhouette score.
#
# > The silhouette score measures how similar a point is to its own cluster compared to other clusters. Scores closer to 1 indicate better separation. Although the best silhouette score may be 2 clusters, choosing 3 clusters is reasonable because the Iris dataset is known to contain 3 actual species.

# %% [markdown]
# ### Task: Perform KMeans Clustering
#
# **Perform KMeans clustering with the optimal number of clusters**

# %%
# Add your code to perform KMeans clustering using the optimal number of clusters you selected
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(features)

# This last part has been created for you - ensure you do not change this part to maintain continuity with other sections.
# df_scaled['y_pred'] = kmeans.labels_
iris['y_pred'] = kmeans.labels_

# df_scaled.head()
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  y_pred
# 0           5.1          3.5           1.4          0.2  setosa       1
# 1           4.9          3.0           1.4          0.2  setosa       1
# 2           4.7          3.2           1.3          0.2  setosa       1
# 3           4.6          3.1           1.5          0.2  setosa       1
# 4           5.0          3.6           1.4          0.2  setosa       1

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principal_components = pca.fit_transform(features)
# df_scaled['pc1'] = principal_components[:, 0]
# df_scaled['pc2'] = principal_components[:, 1]
iris['pc1'] = principal_components[:, 0]
iris['pc2'] = principal_components[:, 1]

# Plot the clusters
plt.figure(figsize=(8, 6))
# sns.scatterplot(x='pc1', y='pc2', hue='y_pred', palette='Set1', data=df_scaled)
sns.scatterplot(x='pc1', y='pc2', hue='y_pred', palette='Set1', data=iris)
plt.title('KMeans Clustering of Iris Dataset (PCA-reduced)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Cluster')
plt.show()

# %% [markdown]
# *Optional:*
#
# If you want to visualize the data you may want to carry out a [PCA](https://scikit-learn.org/stable/auto_examples/decomposition/plot_pca_iris.html#sphx-glr-auto-examples-decomposition-plot-pca-iris-py)
#
# PCAs can help us visualize and characterise data sets, particularly when the number of features exceeds our spatial dimensions. Here is a simple example but the previous link is also worth exploring:
#
# ```python
# from sklearn.decomposition import PCA
#
# pca = PCA(n_components=2)
# principal_components = pca.fit_transform(features)
# df_scaled['pc1'] = principal_components[:, 0]
# df_scaled['pc2'] = principal_components[:, 1]
#
# # Plot the clusters
# plt.figure(figsize=(8, 6))
# sns.scatterplot(x='pc1', y='pc2', hue='y_pred', palette='Set1', data=df_scaled)
# plt.title('KMeans Clustering of Iris Dataset (PCA-reduced)')
# plt.xlabel('Principal Component 1')
# plt.ylabel('Principal Component 2')
# plt.legend(title='Cluster')
# plt.show()
# ```

# %% [markdown]
# ### Cluster Evaluation and Interpretation

# %% [markdown]
# #### Generate a Confusion Matrix
#
# One of the most useful visualizations we can create to evaluate a classification model is a confusion matrix. Supposedly, the term confusion refers to "the confusion of the model" but it may also be that they can be a bit confusing at first.
#
# A confusion matrix provides a 2D plot of actual and predicted values, allowing us to determine both **false positive** and **true positive** as well as **false negatives** and **true negatives**, depending on our business case we may put more weight on any of these. Where confusion matrices can get confusing is that we often want to determine these values where there are more than 2 classifications.
#
# Further, to create a confusion matrix, we need to compare like-for-like and recall that in our example we started with a species (string) and what we got were labels (integers between 0-3). So if we try and see how often our clusters (y_pred) match the species, we are going to find "never" as the answer.
#
# So, in order to even begin a comparison, we need to *map* the clusters to their respective names or what they mean to us - but how?
#
# A common way is to start with optimism and assume that the guess the model makes most frequently is probably right and then we have a mapping. Let's look at an example from our data set:

# %%
# (df_scaled[df_scaled['y_pred'] == 0] # filters the data set to just those rows with the label 0, whatever that means...
(iris[iris['y_pred'] == 0]
['species'] # gets just the species column from the filtered set
 .mode() # returns the values sorted by frequencies (ie. most frequent values first)
 [0] # get that first value (most common)
) # ---> 'virginica' so whenever our model assigns the label '0', it is most commonly virginica...
# Out:
# 'virginica'

# %% [markdown]
# We can do this automatically (gets tedious) if there are a lot of labels, by iterating over each predicted y value (cluster) and repeating the code above. We'll leave it to you as an optional exercise to do that (what isn't optional is you have to figure out what the other clusters mean yourself - sorry). For now, to emphasize the point, we will begin by *arbitrarily* mapping the species to a cluster value.

# %%
# name_to_value_map = {'setosa': 0, 'versicolor': 1, 'virginica': 2} # just guessing here!
name_to_value_map = {'virginica': 0, 'setosa': 1, 'versicolor': 2}
# df_scaled['y_true'] = df_scaled.species.map(name_to_value_map)
iris['y_true'] = iris.species.map(name_to_value_map)

# %% [markdown]
# Now, we have two columns `y_true` and `y_pred` each containing the values 0, 1, 2. We can compare them.

# %%
from sklearn.metrics import confusion_matrix # didn't think we'd do it ourselves did you?
# confusion_matrix(df_scaled['y_true'], df_scaled['y_pred'])
confusion_matrix(iris['y_true'], iris['y_pred'])
# Out:
# array([[36,  0, 14],
#        [ 0, 50,  0],
#        [ 3,  0, 47]])

# %% [markdown]
# That's nice - but it's already very confusing and hard to interpret - so we usually visualize this matrix, and of course, scikit-learn does that for us too!

# %%
from sklearn.metrics import ConfusionMatrixDisplay
# ConfusionMatrixDisplay.from_predictions(df_scaled.y_true, df_scaled.y_pred, cmap=plt.cm.Blues);
ConfusionMatrixDisplay.from_predictions(iris.y_true, iris.y_pred, cmap=plt.cm.Blues);

# %% [markdown]
# Oh no! The diagonal of a confusion matrix tells us the **true positives**, and looking at this one, well, it is all 0's, meaning we didn't get the species right even once.
#
# It looks like our model did terribly.
#
# But then you recall that the labels we assigned were utterly arbitrary.

# %% [markdown]
# #### Task: Fix the matrix as best you can
#
# Using your preferred technique (manually, using modes, or by inspecting the confusion matrix). When you have got the best model, try running KMeans on the unscaled data and compare the results. Discuss the comparative performance here and use the better model for subsequent questions.
#
# > Did the scaled or unscaled model work better? Did this tell us anything interesting about the relative contribution of sepal length and width and petal length and width in discriminating iris species? (Hint, you may want to try min/max on the unscaled values of each of these)

# %% [markdown]
# #### Task: Interpret the Confusion Matrix
# > Complete the questions below
#
# 1. Briefly summarize what the matrix shows (interpret the column, rows, values/color gradient)
# > We didn't get any of the species of the iris right.
# 2. Given the matrix results, assign a species that corresponds to each cluster label
# > virginica is the best one for 0, setosa is the best for 1 and versicolor is the best for 2. Although there aren't that many many versicolor in 2 compared to 0.
# 3. Which species is the model likely to do the best job at correctly identifying and why?
# > Setosa. Because setosa is the one that was the most distinct compared to the other two.
# 4. Which species is most likely to be confused by another species?
# > Versicolor and virginica. When looking at the confusion matrix, versicolor and virginica almost appear in the same cluster. Though, it may be versicolor as virginica hasn't appeared in other species in the confusion matrix.

# %% [markdown]
# ## Hypothesis Development and Significance Testing

# %% [markdown]
# ### Task: Develop an hypothesis

# %% [markdown]
# Examine the diagonal of the pairplot below, and identify a feature that overlaps the most between two species.
#
# 1. What feature and what two species did you identify and why?
#
# > Sepal_width between versicolor and virginica.

# %%
sns.pairplot(iris, hue='species');

# %% [markdown]
# #### Task: Split the feature into two groups

# %%
# complete the code below
versicolor_sw = iris[iris.species == 'versicolor'].sepal_width
virginica_sw = iris[iris.species == 'virginica'].sepal_width

# %%
# Use a more meaningful name (that you came up with earlier)
versicolor_sw.mean(),virginica_sw.mean()
# Out:
# (np.float64(2.7700000000000005), np.float64(2.974))

# %% [markdown]
# ### Task: Formulate a Hypothesis
#
# The mean value between the two groups is unquestionably different. It's just a fact. But this fact only applies to our particular sample. We want to try to figure out how likely it is that this difference will be found in the population. That is we want to test its significance.
#
# Significance testing and hypothesis testing are sometimes used interchangeably.
#
# Given the species and feature you found, formulate a hypothesis:
#
# > H0 = There is no difference between the sepal width of these two species of iris
#
# > H1 = There is a difference between the sepal width of these two species of iris
#
# To develop confidence in our hypothesis, we want to ask the following question:
#
# *Suppose that in our population, on average, there is no difference between the two populations. How likely would we find a difference like the one we did by chance alone?*
#
# The hypothesis that chance alone can explain a difference between groups is called the **null hypothesis**.
#
# The alternative is that it is doubtful that we would get the difference we measured by chance alone, which is called the **alternative hypothesis**.
# [Reference](https://learning.oreilly.com/library/view/practical-statistics-for/9781492072935/ch03.html#idm45782046480184)
#
# We usually start with the null hypothesis and try to prove how likely it is to be true; if the chance that the null hypothesis is true is very low (different contexts set different thresholds by convention), then we reject the null hypothesis. The probability of getting the difference we observed assuming the populations are identical concerning that feature is typically called the *p-value*. In the business and humanities, a *p-value* of less than 0.05 (meaning less than a 5% chance of getting the difference we observed by chance) is said to be statistically significant.
#
# A common test we can perform on samples is called the t-test and we can use the scipy module to perform advanced statistical analysis

# %%
# Use a more meaningful name (that you came up with earlier)
from scipy.stats import ttest_ind
ttest_ind(versicolor_sw, virginica_sw, equal_var=False)
# Out:
# TtestResult(statistic=np.float64(-3.2057607502218186), pvalue=np.float64(0.0018194834821049707), df=np.float64(97.92682669979344))

# %% [markdown]
# *task: use the previous output to formulate a general conclusion about this feature and how meaningful this difference is in terms of the population.*

# %% [markdown]
# Often when we carry out cluster analysis, we may want to see what the utility of this distinction is in terms of some population metric.

# %% [markdown]
# **Good Luck with your Assessment!**
#
# This assessment is an opportunity to demonstrate your practical skills in data analysis, clustering, and statistical testing using Python. By completing the tasks and meeting the criteria outlined, you will showcase your competency in essential data analytics techniques aligned with industry standards.

# %% [markdown]
# ## Assessor Resources
# > Your assessor will use this section to evaluate your competency

# %% [markdown]
# ### Assessor Instructions
#
# - **Preparation:**
#   - Familiarise yourself with the assessment tasks and criteria.
#   - Ensure you have access to the necessary resources to assess the student's work.
#
# - **During Assessment:**
#   - Review the student's Jupyter Notebook thoroughly.
#   - Cross-reference the student's work with the assessment criteria.
#
# - **Feedback:**
#   - Provide clear and constructive feedback, highlighting strengths and improvement areas.
#   - Encourage the student to reflect on their learning and understanding.
#
# - **Recording Results:**
#   - Use the provided table to mark each criterion as **CO** or **NYC**.
#   - Complete the overall competency determination based on the criteria.
#
#
# ---

# %% [markdown]
# ### **Assessment Tasks and Criteria**
#
# | **Task** | **Assessment Criteria**                                                                                                                                                                                                       | **CO** | **NYC** |
# |----------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------|---------|
# | **1. Data Preparation and Normalisation** |                                                                                                                                                                                                                                       |        |         |
# | 1.1 Load and Evaluate the Dataset | - Correctly loads the Iris dataset using appropriate Python libraries.<br>- Verifies data integrity by checking for missing values and data types.<br>- Provides a brief explanation of data quality in markdown cells.                       |        |         |
# | 1.2 Apply Data Normalisation Techniques | - Identifies and explains appropriate data normalisation methodologies.<br>- Applies StandardScaler to normalise feature columns.<br>- Explains the importance of data normalisation for KMeans clustering in markdown cells.             |        |         |
# | **2. KMeans Clustering Analysis** |                                                                                                                                                                                                                                           |        |         |
# | 2.1 Determine Optimal Number of Clusters | - Implements the Elbow Method to calculate inertia for k values.<br>- Plots the Elbow Curve and identifies the "elbow".<br>- Calculates Silhouette Scores for k values.<br>- Plots Silhouette Scores and identifies optimal k.<br>- Explains rationale in markdown cells. |        |         |
# | 2.2 Perform KMeans Clustering | - Correctly applies KMeans clustering using the identified optimal k.<br>- Assigns cluster labels to the dataset.<br>- Displays results appropriately.                                                                                          |        |         |
# | 2.3 Evaluate Clustering Using Silhouette Score | - Calculates the Silhouette Score for the clustering.<br>- Interprets the Silhouette Score in the context of cluster separation in markdown cells.                                                                                     |        |         |
# | **3. Cluster Evaluation and Interpretation** |                                                                                                                                                                                                                                       |        |         |
# | 3.1 Generate and Interpret a Confusion Matrix | - Generates a confusion matrix comparing true labels and cluster labels.<br>- Visualises the confusion matrix using a heatmap.<br>- Interprets the confusion matrix and discusses implications in markdown cells.                        |        |         |
# | **4. Hypothesis Development and Significance Testing** |                                                                                                                                                                                                                                       |        |         |
# | 4.1 Develop a Hypothesis | - Formulates a logical and testable hypothesis based on clustering results.<br>- Hypothesis is clearly stated in markdown cells.                                                                                                                     |        |         |
# | 4.2 Conduct a Significance Test | - Selects an appropriate statistical test (e.g., t-test).<br>- Correctly performs the test using Python.<br>- Reports test statistics and p-value accurately.                                                                                |        |         |
# | 4.3 Conclude Findings | - Interprets the results of the significance test in markdown cells.<br>- States whether the null hypothesis is rejected or not.<br>- Conclusion aligns with hypothesis and test results.                                                               |        |         |
# | **5. Presentation and Documentation** |                                                                                                                                                                                                                                       |        |         |
# | 5.1 Organise the Jupyter Notebook | - Notebook is well-structured with clear headings and sections.<br>- All code cells are executed, and outputs are displayed.<br>- Uses markdown cells effectively to separate and explain tasks.                                            |        |         |
# | 5.2 Provide Clear Explanations and Code Comments | - Includes concise and relevant explanations in markdown cells.<br>- Code is commented where necessary for clarity.<br>- Explanations enhance understanding of the process and results.                                               |        |         |

# %% [markdown]
# ### Assessor Feedback Template
#
# - **Areas of Competency Achieved:**
#
#   - [List the tasks where the student is competent.]
#
# - **Areas Requiring Improvement:**
#
#   - [List the tasks where the student is not yet competent.]
#
# - **Recommendations for Further Development:**
#
#   - [Provide guidance on how the student can achieve competency in areas needing improvement.]
